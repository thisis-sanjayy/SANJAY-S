# %% [markdown]
# <a href="https://colab.research.google.com/github/thisis-sanjayy/SANJAY-S/blob/main/firstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
model = tf.keras.models.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
xs = np.array([-1.0, 0.0, 1.0], dtype=float)
ys = np.array([-1.0, 1.0, 3.0], dtype=float)
model.fit(xs, ys, epochs=500)
print(model.predict(np.array([20.0])))
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - loss: 6.1818
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 6.0049
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 5.8333
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 5.6667
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.5050
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.3480
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.1956
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 5.0477
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.9041
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 4.7647
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.6294
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.4980
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 4.3704
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 4.2466
# Epoch 15/500
# ...
